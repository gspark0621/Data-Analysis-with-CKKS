# %% [markdown]
# ## Setting
# - Desilo key 생성

# %%
from desilofhe import Engine

engine = Engine(use_bootstrap=True, mode="gpu")

secret_key = engine.create_secret_key()
public_key = engine.create_public_key(secret_key)
relinearization_key = engine.create_relinearization_key(secret_key)
conjugation_key = engine.create_conjugation_key(secret_key)
bootstrap_key = engine.create_bootstrap_key(secret_key)
rotation_key = engine.create_rotation_key(secret_key)

# %% [markdown]
# Import 안될 때 해결법
# - __pycache__속 파일 삭제
# - 하단 코드에서 내가 원하는 파일의 이름을 Basic_operations 대신 입력 후 실행

# %%
import importlib
import Basic_operations
importlib.reload(Basic_operations)
# Out:
# <module 'Basic_operations' from '/home/junhyung/study/Data-Analysis-with-CKKS/Approximation_in_CKKS/desilo/Basic_operations.py'>

# %% [markdown]
# Min/max Algorithm
# - Min/max between two numbers
# - Min/max between several numbers
# - Max index는 Comp.에서 진행

# %%
# Min/max between two numbers
from Basic_operations import Basic_sqrt

def CKKS_min(engine, a, b, d, relinearization_key, conjugation_key, bootstrap_key): # 0 <= x < 1
    x = engine.multiply(engine.add(a,b),0.5) # x= (a+b)/2
    y = engine.multiply(engine.subtract(a,b),0.5) # y= (a-b)/2
    y_2 = engine.square(y, relinearization_key) # y^2
    z= Basic_sqrt(engine, y_2, d, relinearization_key, conjugation_key, bootstrap_key)
    return engine.subtract(x,z)

def CKKS_max(engine, a, b, d, relinearization_key, conjugation_key, bootstrap_key): # 0 <= x < 1
    x = engine.multiply(engine.add(a,b),0.5) # x= (a+b)/2
    y = engine.multiply(engine.subtract(a,b),0.5) # y= (a-b)/2
    y_2 = engine.square(y, relinearization_key)
    z= Basic_sqrt(engine, y_2, d, relinearization_key, conjugation_key, bootstrap_key)
    return engine.add(x,z)

def main():
    data = [1,10,5]
    data_2 = [2,3,7]
    scale_down_factor = 20

    val1_scaled_down = [x / scale_down_factor for x in data]
    val2_scaled_down = [x / scale_down_factor for x in data_2]

    enc_orig1 = engine.encrypt(val1_scaled_down, public_key)
    enc_orig2 = engine.encrypt(val2_scaled_down, public_key)

    # min,max 연산 SIMD 병렬 처리 (전체 벡터 한번에)
    min_val_scaled_down = CKKS_min(engine, enc_orig1, enc_orig2, 23, relinearization_key, conjugation_key, bootstrap_key)
    max_val_scaled_down = CKKS_max(engine, enc_orig1, enc_orig2, 23, relinearization_key, conjugation_key, bootstrap_key)

    plt_min_val = engine.decrypt(min_val_scaled_down, secret_key)
    plt_max_val = engine.decrypt(max_val_scaled_down, secret_key)

    # 각 요소별 출력
    for i in range(len(data)):
        print(f"\n=== {i}번째 비교: {data[i]}와 {data_2[i]}간의 비교===")
        print(f"Min({data[i]} and {data_2[i]}) = {plt_min_val[i] * scale_down_factor}")
        print(f"Max({data[i]} and {data_2[i]}) = {plt_max_val[i] * scale_down_factor}")

    return 0



if __name__ == '__main__':
    main()
# Out:
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#
# === 0번째 비교: 1와 2간의 비교===
# Min(1 and 2) = (1.0034680598852035-0.00013821973326953388j)
# Max(1 and 2) = (1.996531940115003+0.00013821973326993097j)
#
# === 1번째 비교: 10와 3간의 비교===
# Min(10 and 3) = (3.0093234972754805-6.690977749050222e-05j)
# Max(10 and 3) = (9.990676502724474+6.690977748141495e-05j)
#
# === 2번째 비교: 5와 7간의 비교===
# Min(5 and 7) = (5.003448296117362-7.044110562899604e-05j)
# Max(5 and 7) = (6.996551703882598+7.044110562205308e-05j)

# %%
# Min/max between several numbers
# Tree 생성 후 탐색을 진행하기 때문에 data element마다 encrypt 필요
from Basic_operations import CKKS_min, CKKS_max

def array_max(engine, enc_values, d,relinearization_key, conjugation_key, bootstrap_key): #0 <= x < 1
    # 논문은 n이 2의 거듭제곱일 때 분석 편함
    current_arr = []
    current_arr.append(enc_values)
    j=0
    while len(current_arr[j]) > 1:
        prev_level = current_arr[j]
        next_level = []
        
        length = len(prev_level)
        # 홀수일 경우 마지막 원소 단독 승계
        if length % 2 == 1:
            next_level.append(prev_level[-1])
            length -= 1
        
        for i in range(0, length, 2):
            m = CKKS_max(engine, prev_level[i], prev_level[i+1],d, relinearization_key, conjugation_key, bootstrap_key)  # 논문 Max 근사 함수
            next_level.append(m)
        
        current_arr.append(next_level)
        j += 1
    return current_arr[-1][0]  # 최상위(마지막) 레벨의 첫 요소 ≈ 전체 배열의 최대값 근사치

def array_min(engine, enc_values, d,relinearization_key, conjugation_key, bootstrap_key): #0 <= x < 1
    # 논문은 n이 2의 거듭제곱일 때 분석 편함
    current_arr = []
    current_arr.append(enc_values)
    j=0
    while len(current_arr[j]) > 1:
        prev_level = current_arr[j]
        next_level = []
        
        length = len(prev_level)
        # 홀수일 경우 마지막 원소 단독 승계
        if length % 2 == 1:
            next_level.append(prev_level[-1])
            length -= 1
        
        for i in range(0, length, 2):
            m = CKKS_min(engine, prev_level[i], prev_level[i+1],d, relinearization_key, conjugation_key, bootstrap_key)  # 논문 Max 근사 함수
            next_level.append(m)
        
        current_arr.append(next_level)
        j += 1
    return current_arr[-1][0] 


def main():
    
    data = [1,2,7,9,5,6,3,8,4,10]
    scale_down_factor = 20
    # 1. 데이터 스케일링 후 암호화
    enc_orig = []
    for i in range(len(data)):
        val1_scaled_down = [data[i] / scale_down_factor]
        enc_orig.append(engine.encrypt(val1_scaled_down, public_key))


    # 2. arraymin, arraymax 연산 적용
    max_val_scaled_down = array_max(engine, enc_orig, 10, relinearization_key, conjugation_key, bootstrap_key)
    min_val_scaled_down = array_min(engine, enc_orig, 10, relinearization_key, conjugation_key, bootstrap_key)
   
    max_val_restored = engine.decrypt(max_val_scaled_down, secret_key)[0] * scale_down_factor
    min_val_restored = engine.decrypt(min_val_scaled_down, secret_key)[0] * scale_down_factor
    
    
    # 3. 복호화 및 출력
    print(f"Input data = {data}")
    print(f"\n=== ArrayMax ===")
    print(f"ArrayMax = {max_val_restored}")   
    print(f"\n=== ArrayMin ===")
    print(f"ArrayMax = {min_val_restored}")
    return 0


if __name__ == '__main__':
    main()
# Out:
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
#     Bootstrapping performed
# ...

# %% [markdown]
# Comp. Algorithm
#
# - Comp. between two numbers
# - MaxIndex/MinIndex

# %%
# Comp between two numbers (논문 Algorithm 5 기반)
from Basic_operations import Basic_Inv

def comp(engine, a, b, d_a, d_b, t, m,
                         relinearization_key, conjugation_key, bootstrap_key):
    # 입력 스케일: 1/2 <= a,b < 3/2 가정
    a_2  = engine.multiply(a, 0.5)
    a_b  = engine.add(a, b)
    ab_2 = engine.multiply(a_b, 0.5)

    # Step 1–2: 1-노름 정규화 a <- a/(a+b), b <- 1-a
    inv0 = Basic_Inv(engine, ab_2, d_a, relinearization_key)
    a    = engine.multiply(a_2, inv0, relinearization_key)
    b    = engine.subtract(1, a)

    # Step 3: (a_m, b_m) 거듭제곱 강조 후 합으로 나눈 정규화, t회 반복
    for _ in range(t):
        a_m = a
        b_m = b

        # 레벨 부족 시 부트스트래핑으로 복구 (선택적)
        if (a.level   < (d_b + 3) or b.level   < (d_b + 3) or
            a_m.level < (d_b + 3) or b_m.level < (d_b + 3)):
            a   = engine.bootstrap(a,   relinearization_key, conjugation_key, bootstrap_key)
            b   = engine.bootstrap(b,   relinearization_key, conjugation_key, bootstrap_key)
            a_m = engine.bootstrap(a_m, relinearization_key, conjugation_key, bootstrap_key)
            b_m = engine.bootstrap(b_m, relinearization_key, conjugation_key, bootstrap_key)
            print("Bootstrap performed")
        # a_m = a^m, b_m = b^m
        for _ in range(m - 1):
            a_m = engine.multiply(a_m, a, relinearization_key)
            b_m = engine.multiply(b_m, b, relinearization_key)

        # 필요시 재부트스트랩
        if (a.level   < (d_b + 3) or b.level   < (d_b + 3) or
            a_m.level < (d_b + 3) or b_m.level < (d_b + 3)):
            a   = engine.bootstrap(a,   relinearization_key, conjugation_key, bootstrap_key)
            b   = engine.bootstrap(b,   relinearization_key, conjugation_key, bootstrap_key)
            a_m = engine.bootstrap(a_m, relinearization_key, conjugation_key, bootstrap_key)
            b_m = engine.bootstrap(b_m, relinearization_key, conjugation_key, bootstrap_key)
            print("Bootstrap performed")

        # 정규화: a <- a_m / (a_m + b_m), b <- 1 - a
        denom_inv = Basic_Inv(engine, engine.add(a_m, b_m), d_b, relinearization_key)
        a = engine.multiply(a_m, denom_inv, relinearization_key)
        b = engine.subtract(1, a)

    # 반환: 비교 지표(0~1), 1에 가까우면 a>b
    return a

def main():
    data   = [1,2,7,9,5,6,3,8,4,10]
    data_1 = [3,8,4,10,1,2,7,9,5,6]

    # 1/2~3/2 범위를 맞추기 위한 예시 스케일링(0.5 + x/10)
    scale_down_factor = 10
    val1 = [0.5 + (x / scale_down_factor) for x in data]
    val2 = [0.5 + (x / scale_down_factor) for x in data_1]

    enc1 = engine.encrypt(val1, public_key)
    enc2 = engine.encrypt(val2, public_key)

    # Comp 실행 (예: d_a=5, d_b=6, t=13, m=8)
    comp_out = comp(engine, enc1, enc2, 5, 6, 13, 8,
                                    relinearization_key, conjugation_key, bootstrap_key)

    # 복호화: 실수부만 사용
    dec = engine.decrypt(comp_out, secret_key)
    dec_real = [z.real for z  in dec]
    # 판정: 0.5 임계
    for i in range(len(data)):
        print(f"\n=== {i}번째 비교: {data[i]} vs {data_1[i]} ===")
        if dec_real[i] > 0.5:
            print(f"{data[i]} > {data_1[i]}")
        else:
            print(f"{data[i]} <= {data_1[i]}")
        # 디버그: 연속값도 함께 확인
        print(f"comp_out ≈ {dec_real[i]:.6f}")
    return 0

if __name__ == '__main__':
    main()
# Out:
# === 0번째 비교: 1 vs 3 ===
# 1 <= 3
# comp_out ≈ -0.000000
#
# === 1번째 비교: 2 vs 8 ===
# 2 <= 8
# comp_out ≈ -0.000000
#
# === 2번째 비교: 7 vs 4 ===
# 7 > 4
# comp_out ≈ 1.001528
#
# === 3번째 비교: 9 vs 10 ===
# 9 <= 10
# comp_out ≈ 0.000000
#
# === 4번째 비교: 5 vs 1 ===
# 5 > 1
# comp_out ≈ 1.001529
#
# === 5번째 비교: 6 vs 2 ===
# 6 > 2
# comp_out ≈ 1.001527
#
# === 6번째 비교: 3 vs 7 ===
# 3 <= 7
# comp_out ≈ 0.000000
#
# === 7번째 비교: 8 vs 9 ===
# 8 <= 9
# comp_out ≈ 0.000000
#
# === 8번째 비교: 4 vs 5 ===
# 4 <= 5
# comp_out ≈ -0.000000
#
# === 9번째 비교: 10 vs 6 ===
# 10 > 6
# comp_out ≈ 1.001528

# %%
# MaxIdx (Bootstrapping으로 인해 결과물에 오차 발생)
from Basic_operations import Basic_Inv
import numpy as np

def rotate_sum(engine, enc_vec, n, rotation_key):
    # Sum of all n slots in a packed vector (cyclic rotations)
    result = enc_vec
    rotated = enc_vec
    for _ in range(n):
        rotated = engine.rotate(rotated, rotation_key, -1)  # rotate by -1 each time
        result = engine.add(result, rotated)
    return result

def MaxIdx(engine, enc_values, n, d_a, d_b, t, m, relinearization_key, rotation_key, conjugation_key=None, bootstrap_key=None):
    
    # 1) Initial 1-norm normalization: b_j = a_j / sum(a)
    sum_a = rotate_sum(engine, enc_values, n, rotation_key)                     # Σ a_j
    inv_sum = Basic_Inv(engine, sum_a, d_a, relinearization_key)                # ≈ 1 / Σ a_j
    b = engine.multiply(enc_values, inv_sum, relinearization_key)               # b ← a * inv(Σ a)

    # 2) Iterations: b ← (b^m) / (Σ b^m)
    for _ in range(t):
        # Compute b^m
        b_m = b

        # Optional: fixed-position bootstrap to reduce run-to-run variability
        if b.level < (m + d_b + 2) or b_m.level < (m + d_b + 2):
            b = engine.bootstrap(b, relinearization_key, conjugation_key, bootstrap_key)
            b_m = engine.bootstrap(b_m, relinearization_key, conjugation_key, bootstrap_key)
            print("Bootstrap performed")

        for _ in range(m - 1):
            b_m = engine.multiply(b_m, b, relinearization_key)

        # Sum s = Σ b^m and invert
        s = rotate_sum(engine, b_m, n, rotation_key)
        inv_s = Basic_Inv(engine, s, d_b, relinearization_key)

        # Re-normalize: b ← b^m * inv_s
        b = engine.multiply(b_m, inv_s, relinearization_key)

    # Output: b is approximately one-hot on the max index
    return b

def main():
    # Example data; pack into [1/2, 3/2] as recommended
    data = [1,2,7,9,5,6,10,3,8,4]  # max at index 5 (0-based)
    scale_down_factor = 20
    vals_scaled = [0.5 + (x / scale_down_factor) for x in data]  # -> roughly [0.55 .. 1.0]

    enc_orig = engine.encrypt(vals_scaled, public_key)

    # Parameters: tune per modulus chain and desired margin c
    b = MaxIdx(engine, enc_orig, len(data), d_a=5, d_b=5,t=6, m=4, relinearization_key=relinearization_key, rotation_key=rotation_key, conjugation_key=conjugation_key, bootstrap_key=bootstrap_key)
    b_dec = engine.decrypt(b, secret_key)[:len(data)]
    b_real = np.real(np.array(b_dec))
    max_index = int(np.argmax(b_real))
    print(f"최대값 위치 (0-based): {max_index}")
    print(f"최대값 위치 (1-based): {max_index + 1}")

if __name__ == '__main__':
    main()
# Out:
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# 최대값 위치 (0-based): 9
# 최대값 위치 (1-based): 10

# %% [markdown]
# Threshold Count
# - 특정 값(b)보다 큰(작은)수를 count하는 함수의 CKKS(Desilo) 근사 구현

# %%
# Threshold Count

from Basic_operations import CKKS_comp

def rotate_sum(engine, enc_vec, num_slots, rotation_key):
    result = engine.clone(enc_vec)
    rotated = enc_vec
    for _ in range(num_slots):
        rotated = engine.rotate(rotated, rotation_key, -1)
        result = engine.add(result, rotated)
    return result

def Threshold(engine, enc_value, b, n, d_a , d_b , t, m,  relinearization_key, conjugation_key, bootstrap_key, rotation_key):# 입력 스케일: 1/2 <= a,b < 3/2 가정(∵comp 알고리즘
    c = CKKS_comp(engine, enc_value, b, d_a, d_b, t, m,  relinearization_key, conjugation_key, bootstrap_key) 
    sum_ct = rotate_sum(engine, c, n, rotation_key)      
    return sum_ct

def main():
    data = [1,2,7,9,6,10,3,8,4]
    scale_down_factor = 20
    data_scaled = [0.5 + (x / scale_down_factor) for x in data]
    Threshold_num = 5 # Threshold: 6
    Threshold_scaled = [0.5 + (6 / scale_down_factor)] * len(data)
    
    enc_orig = engine.encrypt(data_scaled, public_key)
    enc_threshold  = engine.encrypt(Threshold_scaled, public_key)
    
    Threshold_count = Threshold(engine, enc_orig, enc_threshold, len(data), 5, 5, 6, 4, relinearization_key, conjugation_key, bootstrap_key, rotation_key)
    Threshold_count_plt = engine.decrypt(Threshold_count, secret_key).real[0]
    # Threshold보다 큰 수의 개수
    print(f"Threshold인 {Threshold_num}보다 큰 수의 개수: {int(Threshold_count_plt)}개")

    return 0

if __name__ == '__main__':
    main()
# Out:
# Threshold인 5보다 큰 수의 개수: 5개

# %% [markdown]
# Top-k Max algorithm
# - 상위 k개 max값을 추출하는 함수의 CKKS(Desilo) 근사 구현

# %%
#Top-k Max algorithm(MaxIdx의 오차때문에 정확한 k개 값 도출 어려움)

from Basic_operations import MaxIdx
import numpy as np

def rotate_sum(engine, enc_vec, num_slots, rotation_key):
    result = engine.clone(enc_vec)
    rotated = enc_vec
    for _ in range(num_slots):
        rotated = engine.rotate(rotated, rotation_key, -1)
        result = engine.add(result, rotated)
    return result

def Top_k_max(engine, enc_value, n, d_a, d_b, t, m, k, relinearization_key, rotation_key, conjugation_key, bootstrap_key):
    c = enc_value
    result = []

    for j in range(k):
        # 1) b ← MaxIdx(c)
        b = MaxIdx(engine, c, n, d_a, d_b, t, m,relinearization_key, rotation_key,conjugation_key,bootstrap_key)
        # 필요 시 최소 부트스트랩 (레벨 여유 없을 때만)
        if c.level < n+3 or b.level < n+2:
            b = engine.bootstrap(b, relinearization_key, conjugation_key, bootstrap_key)
            c = engine.bootstrap(c, relinearization_key, conjugation_key, bootstrap_key)
            print("Bootstrap performed")

        # 2) m_j = Σ_i b_i * c_i  (슬롯별 Hadamard 곱 후 회전합으로 0번 슬롯로 모음)
        prod = engine.multiply(c, b, relinearization_key)
        m_j = rotate_sum(engine, prod, n, rotation_key)
        result.append(m_j)

        # 3) c ← (1 - b) ⊙ c  (선택된 최대 성분 제거)
        enc_one = engine.encrypt([1.0]*n, public_key)
        one_minus_b = engine.subtract(enc_one, b)
        c = engine.multiply(one_minus_b, c, relinearization_key)

    return result # k개 리스트(각 top-1, top-2, ... 위치 값)


def main():
    data = [1,2,7,9,5,10,6,3,8,4]
    scale_down_factor = 10
    data_scaled = [x / (scale_down_factor*len(data)) for x in data]
    k_value = 4 # Top-k에서 k 값 설정
    
    enc_orig = engine.encrypt(data_scaled, public_key)
    Top_K_value = Top_k_max(engine, enc_orig, len(data), 5, 5, 6, 4, k_value, relinearization_key, rotation_key, conjugation_key, bootstrap_key)
    Top_k_value_plt = []
    for i in range(k_value):
        Top_k_value_plt.append(engine.decrypt(Top_K_value[i],secret_key)[0])
    print(f"Top-{k_value} Max 값: {(np.real(Top_k_value_plt))*scale_down_factor*len(data)}")


if __name__ == '__main__':
    main()
# Out:
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Bootstrap performed
# Top-4 Max 값: [4.00006986 7.99995922 3.00014526 5.99998955]
